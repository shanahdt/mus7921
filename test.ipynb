# %%
5+5
# Out:
# [1] 10

# %%
15/4
# Out:
# [1] 3.75

# %%
mydata <- c(4,5,6,4,3,4,5)
plot(mydata)
# Out:
# plot without title

# %% [markdown]
# ### Subtitle here

# %% [markdown]
# This works well, overall. I always write that when testing things that I'll never use again. Ugh.
